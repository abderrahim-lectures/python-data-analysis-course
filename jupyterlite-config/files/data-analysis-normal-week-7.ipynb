# %% [markdown]
# # Week 7: Selection, Filtering & Indexing
#
# Starter notebook for [/docs/data-analysis/normal/week-7](/docs/data-analysis/normal/week-7). The dataset `students-normal.csv` is already in this notebook's working directory — just `pd.read_csv("students-normal.csv")`, no download needed.

# %%
import pandas as pd

df = pd.read_csv("students-normal.csv")
# Try: df[df["quiz1"] >= 60]
df.head()

# %%
# Your work here
