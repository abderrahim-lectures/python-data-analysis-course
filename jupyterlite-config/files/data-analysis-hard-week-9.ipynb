# %% [markdown]
# # Week 9: Advanced & Storytelling Visualizations
#
# Starter notebook for [/docs/data-analysis/hard/week-9](/docs/data-analysis/hard/week-9). The dataset `students-performance.csv` is already in this notebook's working directory — just `pd.read_csv("students-performance.csv")`, no download needed.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("students-performance.csv")
sns.boxplot(data=df, x="test_preparation_course", y="math_score")
plt.show()

# %%
# Your work here
