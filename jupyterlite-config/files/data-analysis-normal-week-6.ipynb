# %% [markdown]
# # Week 6: Series & DataFrame Basics
#
# Starter notebook for [/docs/data-analysis/normal/week-6](/docs/data-analysis/normal/week-6). The dataset `students-normal.csv` is already in this notebook's working directory — just `pd.read_csv("students-normal.csv")`, no download needed.

# %%
import pandas as pd

df = pd.read_csv("students-normal.csv")
df.head()

# %%
# Your work here
