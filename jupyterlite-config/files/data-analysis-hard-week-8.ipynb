# %% [markdown]
# # Week 8: Bivariate & Multivariate Analysis
#
# Starter notebook for [/docs/data-analysis/hard/week-8](/docs/data-analysis/hard/week-8). The dataset `students-performance.csv` is already in this notebook's working directory — just `pd.read_csv("students-performance.csv")`, no download needed.

# %%
import pandas as pd

df = pd.read_csv("students-performance.csv")
df[["math_score", "reading_score", "writing_score"]].corr()

# %%
# Your work here
