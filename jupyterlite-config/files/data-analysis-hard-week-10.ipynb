# %% [markdown]
# # Week 10: Final Deliverable — Students Performance EDA Report
#
# Starter notebook for [/docs/data-analysis/hard/week-10](/docs/data-analysis/hard/week-10). The dataset `students-performance.csv` is already in this notebook's working directory — just `pd.read_csv("students-performance.csv")`, no download needed.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("students-performance.csv")
df["average_score"] = df[["math_score", "reading_score", "writing_score"]].mean(axis=1)
df.head()

# %%
# Your work here
