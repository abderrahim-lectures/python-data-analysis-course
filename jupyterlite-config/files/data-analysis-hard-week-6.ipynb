# %% [markdown]
# # Week 6: The EDA Framework
#
# Starter notebook for [/docs/data-analysis/hard/week-6](/docs/data-analysis/hard/week-6). The dataset `students-performance.csv` is already in this notebook's working directory — just `pd.read_csv("students-performance.csv")`, no download needed.

# %%
import pandas as pd

df = pd.read_csv("students-performance.csv")
df.describe()

# %%
# Your work here
