# %% [markdown]
# # Week 7: Univariate Analysis & Visualization
#
# Starter notebook for [/docs/data-analysis/hard/week-7](/docs/data-analysis/hard/week-7). The dataset `students-performance.csv` is already in this notebook's working directory — just `pd.read_csv("students-performance.csv")`, no download needed.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("students-performance.csv")
df["math_score"].hist(bins=20, edgecolor="black")
plt.show()

# %%
# Your work here
